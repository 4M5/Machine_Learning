# %% [markdown]
# <a href="https://colab.research.google.com/github/4M5/Machine_Learning/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=[[1],[2],[3],[4],[5],[6]]
y=[[1],[4],[9],[16],[25],[36]]
import matplotlib.pyplot as plt
plt.plot(x,y)

#load model
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model2=model.fit(x,y)
ynew=model2.predict(x)
print(ynew)
plt.plot(x,ynew)
print(model2.intercept_,model2.coef_)
import sklearn.metrics as m
print(m.mean_absolute_error(y,ynew))
print(m.mean_squared_error(y,ynew))
print(m.r2_score(y,ynew))
import numpy as np
print(np.sqrt(m.mean_squared_error(y,ynew)))
# Out:
# [[-2.33333333]
#  [ 4.66666667]
#  [11.66666667]
#  [18.66666667]
#  [25.66666667]
#  [32.66666667]]
# [-9.33333333] [[7.]]
# 2.222222222222222
# 6.222222222222218
# 0.9582790091264668
# 2.494438257849293

# %%
#Make regression
from sklearn.datasets import make_regression
x, y = make_regression(n_samples=50, n_features=1, n_targets=1)
print(x.shape)
print(y.shape)
print(x.ndim,y.ndim)
# Out:
# (50, 1)
# (50,)
# 2 1

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model2=model.fit(x,y)
ynew=model2.predict(x)
print(ynew)
print(model2.intercept_,model2.coef_)
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.plot(x,ynew,color="Red")
# Out:
# [-13.15765764 -25.56294304  -4.13466013  27.51296342 -24.40151912
#  -38.35739214  -5.93136985  16.21105328 -19.7360005   -4.65584599
#   37.19748112  10.95219164  16.23356992 -18.83354427  24.21487938
#    4.65034884 -24.09654927  -6.88589327  10.60300759 -12.06113007
#   47.60801304  -8.42960008  -5.05197881 -22.31878973  46.80517321
#   22.64612707 -18.54279906  17.9039116   14.97657902   3.75767127
#  -36.81683848  34.47410296  12.26300163   1.42395996  -6.53356816
#  -19.8375333   -7.89817636   0.27178665  -1.16851464  30.51077034
#  -53.26891996 -14.46808417  27.65916151 -16.99146612 -11.2376057
#   18.3788953   35.03440456 -32.85498896 -35.53274947  29.58380728]
# 2.636779683484747e-16 [25.77356658]

# %%
op=model2.predict([[7]])
print(op)
print(op.ndim)
# Out:
# [180.41496604]
# 1

# %%
import sklearn.metrics as m
print(m.mean_absolute_error(y,ynew))
print(m.mean_squared_error(y,ynew))
print(m.r2_score(y,ynew))
# Out:
# 2.7311486405778852e-15
# 1.2295383284000995e-29
# 1.0

# %%
import numpy as np
print(np.sqrt(m.mean_squared_error(y,ynew)))
# Out:
# 3.5064773325947787e-15

# %% [markdown]
# Fuel cons.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("/content/FuelConsumption.csv")
print(data.head())
data1=data[["ENGINESIZE","CO2EMISSIONS","CYLINDERS"]]
print(data1)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax=fig.add_subplot(121,projection='3d')
ax.scatter(data["ENGINESIZE"],data["CO2EMISSIONS"],data["CYLINDERS"],marker="*")
ax.set_xlabel("EngineSize")
ax.set_ylabel("CO2")
ax.set_zlabel("Cylinde")
a=data[["ENGINESIZE","CO2EMISSIONS"]]
b=data["CYLINDERS"]
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model2=model.fit(a,b)
c=model2.predict(a)
print(c)
ax=fig.add_subplot(122,projection='3d')
ax.scatter(data["ENGINESIZE"],data["CO2EMISSIONS"],c,c="red")
ax.set_xlabel("EngineSize")
ax.set_ylabel("CO2")
ax.set_zlabel("New OP")
# Out:
# [4.16826294 4.67989237 3.41388753 ... 5.49726636 5.65921299 5.79502213]
# Text(0.5, 0, 'New OP')
